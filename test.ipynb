# %%
import pandas as pd

# %%
players = pd.read_csv('./Data/players.csv')

# %%
players
# Out:
#      Unnamed: 0 PLAYER_LAST_NAME PLAYER_FIRST_NAME  PERSON_ID     TEAM_CITY  \
# 0             0          Achiuwa          Precious    1630173       Toronto
# 1             1          Anunoby              O.G.    1628384       Toronto
# 2             2           Banton            Dalano    1630625       Toronto
# 3             3           Barnes           Scottie    1630567       Toronto
# 4             4           Barton              Will     203115       Toronto
# ..          ...              ...               ...        ...           ...
# 540         540           Milton             Shake    1629003  Philadelphia
# 541         541            Niang           Georges    1627777  Philadelphia
# 542         542             Reed              Paul    1630194  Philadelphia
# 543         543         Springer             Jaden    1630531  Philadelphia
# 544         544           Tucker              P.J.     200782  Philadelphia
#
# ...
